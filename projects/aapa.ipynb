# %% [markdown]
# # Dataset: African American Poetry
#
# The [**African American Periodical Poetry** dataset](https://www.responsible-datasets-in-context.com/posts/african-american-periodical-poetry/aa-periodical-poetry.html) contains information about poems published in African American periodicals.
# Dataset adapted from: https://www.responsible-datasets-in-context.com/posts/african-american-periodical-poetry/aa-periodical-poetry.html
# Key columns in the dataset include:
#
# - **author (first last)**: The full name of the poet.
# - **author (last name)**: Last name of the poet
# - **year**: The year when the poem was published.
# - **month**: The month when the poem was published.
# - **title**: The title of the poem.
# - **venue**: The venue where the poem was published in.
# - **form (if known)**: The type of poem (e.g., sonnet, free verse).
# - **gender (if known)**: The gender of the poet.
# - **themes**: The themes of the poem.
# - **text**: The full text of the poem.
# - **published in (city)**: the city where the poem was published.

# %%
# Read in the dataset
import pandas as pd
aap = pd.read_csv("https://raw.githubusercontent.com/melaniewalsh/responsible-datasets-in-context/main/datasets/aa-periodical-poetry/African-American-Periodical-Poetry_1900-1928-Created-by-Amardeep-Singh-and-Kate-Hennessey,-Lehigh-University.csv")

# %% [markdown]
# # Wrangling

# %%
# Calculate the length of each poem:
aap['Poem_Length'] = aap['text'].str.len()
aap.head()
# Out:
#                               title        author (first last)  \
# 0                          New Wars  Benjamin Griffith Brawley
# 1                         A Picture     Olivia Ward Bush-Banks
# 2             The Christmas Reunion         Augustus M. Hodges
# 3  A Memorial of Frederick Douglass            C. Henry Holmes
# 4                 The Negro's Worth       Alonzo Milton Skrine
#
#   author (last name)                                               text  \
# 0            Brawley  HURL on the lance! Break up the ancient peace!...
# 1         Bush-Banks  I drew a picture long ago —\nA picture of a su...
# 2             Hodges  Twas a bright Christmas morning in "Ole Kentuc...
# 3             Holmes  He was a noble hero, born in an humble state,\...
# 4             Skrine  Who casts a slur on Negro worth, a stain on Ne...
#
#        month  year              venue          edited by form (if known)  \
# 0   November  1900  Colored American   Walter W. Wallace  Common Measure
# 1       June  1900  Colored American   Walter W. Wallace  Common Measure
# 2   December  1900  Colored American   Walter W. Wallace             NaN
# 3  September  1900  Colored American   Walter W. Wallace           Elegy
# 4   December  1900  Colored American   Walter W. Wallace             NaN
#
#   gender (if known)                                             themes  \
# 0              male                       Spanish-American War, Empire
# 1            female                                                NaN
# 2              male                                            Slavery
# 3              male                                 Frederick Douglass
# 4              male  Civil War, Spanish-American War, Labor, Slaver...
#
#   second venue published in (city)  Magazine Type  \
# 0          NaN              Boston  Predom. Black
# 1          NaN              Boston  Predom. Black
# 2          NaN              Boston  Predom. Black
# 3          NaN              Boston  Predom. Black
# 4          NaN              Boston  Predom. Black
#
#                                          Author Bio.  Poem_Length
# 0  https://en.wikipedia.org/wiki/Benjamin_Griffit...         1418
# 1  https://en.wikipedia.org/wiki/Olivia_Ward_Bush...         1391
# 2   https://en.wikipedia.org/wiki/Augustus_M._Hodges         4477
# 3                                                NaN         1136
# 4  https://scalar.lehigh.edu/african-american-poe...         1564

# %%
# explodes the dataset by themes.
aap["themes"] = aap["themes"].str.split(", ")
poems_themes = aap.explode('themes')
poems_themes.head()
# Out:
#                               title        author (first last)  \
# 0                          New Wars  Benjamin Griffith Brawley
# 0                          New Wars  Benjamin Griffith Brawley
# 1                         A Picture     Olivia Ward Bush-Banks
# 2             The Christmas Reunion         Augustus M. Hodges
# 3  A Memorial of Frederick Douglass            C. Henry Holmes
#
#   author (last name)                                               text  \
# 0            Brawley  HURL on the lance! Break up the ancient peace!...
# 0            Brawley  HURL on the lance! Break up the ancient peace!...
# 1         Bush-Banks  I drew a picture long ago —\nA picture of a su...
# 2             Hodges  Twas a bright Christmas morning in "Ole Kentuc...
# 3             Holmes  He was a noble hero, born in an humble state,\...
#
#        month  year              venue          edited by form (if known)  \
# 0   November  1900  Colored American   Walter W. Wallace  Common Measure
# 0   November  1900  Colored American   Walter W. Wallace  Common Measure
# 1       June  1900  Colored American   Walter W. Wallace  Common Measure
# 2   December  1900  Colored American   Walter W. Wallace             NaN
# 3  September  1900  Colored American   Walter W. Wallace           Elegy
#
#   gender (if known)                themes second venue published in (city)  \
# 0              male  Spanish-American War          NaN              Boston
# 0              male                Empire          NaN              Boston
# 1            female                   NaN          NaN              Boston
# 2              male               Slavery          NaN              Boston
# 3              male    Frederick Douglass          NaN              Boston
#
#    Magazine Type                                        Author Bio.  \
# 0  Predom. Black  https://en.wikipedia.org/wiki/Benjamin_Griffit...
# 0  Predom. Black  https://en.wikipedia.org/wiki/Benjamin_Griffit...
# 1  Predom. Black  https://en.wikipedia.org/wiki/Olivia_Ward_Bush...
# 2  Predom. Black   https://en.wikipedia.org/wiki/Augustus_M._Hodges
# 3  Predom. Black                                                NaN
#
#    Poem_Length
# 0         1418
# 0         1418
# 1         1391
# 2         4477
# 3         1136

# %% [markdown]
# # visualizations

# %% [markdown]
# ## Histograms

# %%
# Visualize: How many times each theme is represented.
import plotly.express as px
fig = px.histogram(poems_themes, x='themes')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="17a9faf5-57a5-4d23-815b-bca18d8300c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17a9faf5-57a5-4d23-815b-bca18d8300c8")) {                    Plotly.newPlot(                        "17a9faf5-57a5-4d23-815b-bca18d8300c8",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"themes=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Spanish-American War","Empire",null,"Slavery","Frederick Douglass","Civil War","Spanish-American War","Labor","Slavery","Progress and Racial Uplift","Lynching and Racialized Violence","Patriotism","Racism","Empire",null,null,null,null,null,null,null,null,null,null,"Intertext","Religion",null,"Slavery","AAVE","AAVE","Paul Laurence Dunbar","Patriotism","AAVE","Religion","AAVE","Religion","Religion","AAVE","AAVE","AAVE",null,null,null,"Slavery","Civil War","Motherhood",null,null,null,null,"Abraham Lincoln","Civil War",null,"Labor","Spanish-American War",null,null,"Intertext","Interracial",null,null,"Abraham Lincoln","Progress and Racial Uplift","Racism","","Religion",null,"Slavery Africa","Travel-Migration-Great Migration","Childhood",null,"Interracial","Black Beauty","Lynching and Racialized Violence",null,"Lynching and Racialized Violence","Intertext","Civil War","Abraham Lincoln","Slavery",null,null,"Scientific Racism","AAVE",null,null,"Africa","Ode","Race",null,"AAVE","Interracial",null,null,"Africa","Labor","Slavery","Religion","Intertext","Progress and Racial Uplift","Religion",null,"Religion","Labor","Progress and Racial Uplift","Racism","Slavery","Religion",null,null,null,null,"Empire","Slavery","Civil War",null,null,null,null,null,"AAVE","Slavery","Labor",null,null,null,"Lincoln","Civil War","Slavery",null,null,null,"Slavery","Labor","AAVE",null,"AAVE","Slavery",null,"AAVE","AAVE",null,null,null,null,"AAVE","Race","Progress-and-Racial Uplift",null,null,null,null,"AAVE",null,null,null,"Progress and Racial Uplift","Travel-Migration-Great Migration",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"Religion: the Black Church","Slavery",null,null,null,null,null,null,"Native American",null,"Progress and Racial Uplift","Civil War","Slavery","Progress and Racial Uplift","Progress and Racial Uplift","AAVE","Travel-Migration-Great Migration",null,"AAVE","Labor",null,"Intertext","Paul Laurence Dunbar",null,null,"Labor","Slavery",null,"Paul Laurence Dunbar","Lynching-and-Racialized-Violence","Intertext","Paul Laurence Dunbar",null,null,null,null,"Civil War","Patriotism",null,"AAVE","Paul Laurence Dunbar",null,null,null,null,"Ars Poetica",null,"Lynching-and-Racialized-Violence","Africa","Labor",null,null,null,null,null,null,"AAVE",null,null,null,null,null,null,"AAVE",null,null,null,null,null,"AAVE","Brownsville","Racism","Military",null,null,null,null,null,"Motherhood",null,"Progress-and-Racial Uplift","Racism","Racism","Childhood",null,null,null,null,"Religion: the Black Church",null,null,"Race","Intertext","Paul Laurence Dunbar","Empire","Racism","Intertext",null,null,null,"Motherhood","Childhood",null,null,"Civil War","Music","Patriotism","Slavery","Slavery","Africa",null,"AAVE","Intertext",null,"Travel-Migration-Great Migration","Caribbean","Caribbean","Interracial-Mixed Race",null,"Intertext",null,null,"Abraham Lincoln","Brownsville Affair","HBCU","Religion","Labor","Racism",null,"AAVE",null,null,null,"AAVE","Labor","Spanish-American War","Patriotism","Lynching and Racialized Violence",null,null,"Limerick",null,null,null,null,"Progress-and-Racial Uplift",nu ...

# %%
# visualize: Occurance of Themes, grouped gender. (i.e., a grouped bar chart)
fig = px.histogram(poems_themes, y='themes',color = "gender (if known)", barmode = "group", height = 2000)
fig.update_yaxes(categoryorder='total ascending')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d6bf02e8-25f0-489a-b78f-ae125a0826c2" class="plotly-graph-div" style="height:2000px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6bf02e8-25f0-489a-b78f-ae125a0826c2")) {                    Plotly.newPlot(                        "d6bf02e8-25f0-489a-b78f-ae125a0826c2",                        [{"alignmentgroup":"True","bingroup":"y","hovertemplate":"gender (if known)=male\u003cbr\u003ecount=%{x}\u003cbr\u003ethemes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"male","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"male","offsetgroup":"male","orientation":"h","showlegend":true,"xaxis":"x","y":["Spanish-American War","Empire","Slavery","Frederick Douglass","Civil War","Spanish-American War","Labor","Slavery","Progress and Racial Uplift","Lynching and Racialized Violence","Patriotism","Racism","Empire",null,null,null,null,null,null,null,null,null,"Intertext","Religion",null,"Slavery","AAVE","AAVE","Paul Laurence Dunbar","Patriotism","AAVE","Religion","AAVE","Religion","Religion","AAVE","AAVE","AAVE",null,null,null,"Slavery","Civil War","Motherhood",null,null,"Abraham Lincoln","Civil War",null,"Labor","Spanish-American War",null,"Intertext","Interracial",null,"Progress and Racial Uplift","Racism","","Religion","Slavery Africa","Travel-Migration-Great Migration",null,"Interracial","Black Beauty","Lynching and Racialized Violence",null,"Lynching and Racialized Violence","Intertext","Civil War","Abraham Lincoln","Slavery",null,"Scientific Racism","AAVE",null,null,"AAVE","Interracial",null,null,"Africa","Labor","Slavery","Religion","Intertext","Progress and Racial Uplift","Religion",null,"Religion","Labor","Progress and Racial Uplift","Racism","Slavery","Religion",null,null,null,null,"Empire","Slavery","Civil War",null,"AAVE","Slavery","Labor",null,null,"Lincoln","Civil War","Slavery",null,null,"Slavery","Labor","AAVE",null,"AAVE","Slavery",null,"AAVE","AAVE",null,null,null,null,"AAVE","Race","Progress-and-Racial Uplift",null,null,null,null,"AAVE",null,null,null,"Progress and Racial Uplift","Travel-Migration-Great Migration",null,null,null,null,null,null,null,"Religion: the Black Church","Slavery",null,null,"Native American","Progress and Racial Uplift","Progress and Racial Uplift","AAVE","Travel-Migration-Great Migration",null,"AAVE","Labor",null,"Intertext","Paul Laurence Dunbar",null,null,"Labor","Slavery","Paul Laurence Dunbar","Intertext","Paul Laurence Dunbar",null,null,null,"Civil War","Patriotism",null,"AAVE","Paul Laurence Dunbar",null,null,null,null,"Ars Poetica",null,"Lynching-and-Racialized-Violence","Africa","Labor",null,null,null,null,null,null,"AAVE",null,null,null,null,null,null,"AAVE",null,null,null,null,"Racism","Childhood",null,null,null,null,null,"Race","Intertext","Paul Laurence Dunbar","Empire","Racism","Intertext","Civil War","Music","Patriotism","Slavery",null,"AAVE","Intertext",null,"Travel-Migration-Great Migration","Caribbean","Caribbean","Interracial-Mixed Race",null,"Intertext",null,"Abraham Lincoln","Brownsville Affair","HBCU","Religion","Labor","Racism",null,"AAVE",null,null,null,"AAVE","Labor","Spanish-American War","Patriotism","Lynching and Racialized Violence",null,null,"Limerick",null,null,null,"Progress-and-Racial Uplift",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"Frederick Douglass",null,null,"Paul Laurence Dunbar",null,null,"Religion",null,null,"Progress and Racial Uplift","Booker T. Washington","",null,"Progress and Racial Uplift","Patriotism","Spanish-American War","Empire","Patriotism","Civil War",null,"Class","Religion","Science","Medicine","AAVE","Progress and Racial Uplift","Religion","Religion","Progress and Racial Uplift","Religion","Ars Poetica","Native American"," ...

# %% [markdown]
# Religion, Racism, Race, Progress and Racial Uplift, and Slavery are the top five themes addressed in African American poetry in this period.

# %%
# Visualize: Persentage of each gender in each theme of the poems.
fig = px.histogram(poems_themes, y='themes',color = "gender (if known)", barnorm = "percent", height = 2000)
fig.update_yaxes(categoryorder='total ascending')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="73207468-9e27-4494-876e-c58ef26ebf72" class="plotly-graph-div" style="height:2000px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73207468-9e27-4494-876e-c58ef26ebf72")) {                    Plotly.newPlot(                        "73207468-9e27-4494-876e-c58ef26ebf72",                        [{"alignmentgroup":"True","bingroup":"y","hovertemplate":"gender (if known)=male\u003cbr\u003ecount (normalized as percent)=%{x}\u003cbr\u003ethemes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"male","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"male","offsetgroup":"male","orientation":"h","showlegend":true,"xaxis":"x","y":["Spanish-American War","Empire","Slavery","Frederick Douglass","Civil War","Spanish-American War","Labor","Slavery","Progress and Racial Uplift","Lynching and Racialized Violence","Patriotism","Racism","Empire",null,null,null,null,null,null,null,null,null,"Intertext","Religion",null,"Slavery","AAVE","AAVE","Paul Laurence Dunbar","Patriotism","AAVE","Religion","AAVE","Religion","Religion","AAVE","AAVE","AAVE",null,null,null,"Slavery","Civil War","Motherhood",null,null,"Abraham Lincoln","Civil War",null,"Labor","Spanish-American War",null,"Intertext","Interracial",null,"Progress and Racial Uplift","Racism","","Religion","Slavery Africa","Travel-Migration-Great Migration",null,"Interracial","Black Beauty","Lynching and Racialized Violence",null,"Lynching and Racialized Violence","Intertext","Civil War","Abraham Lincoln","Slavery",null,"Scientific Racism","AAVE",null,null,"AAVE","Interracial",null,null,"Africa","Labor","Slavery","Religion","Intertext","Progress and Racial Uplift","Religion",null,"Religion","Labor","Progress and Racial Uplift","Racism","Slavery","Religion",null,null,null,null,"Empire","Slavery","Civil War",null,"AAVE","Slavery","Labor",null,null,"Lincoln","Civil War","Slavery",null,null,"Slavery","Labor","AAVE",null,"AAVE","Slavery",null,"AAVE","AAVE",null,null,null,null,"AAVE","Race","Progress-and-Racial Uplift",null,null,null,null,"AAVE",null,null,null,"Progress and Racial Uplift","Travel-Migration-Great Migration",null,null,null,null,null,null,null,"Religion: the Black Church","Slavery",null,null,"Native American","Progress and Racial Uplift","Progress and Racial Uplift","AAVE","Travel-Migration-Great Migration",null,"AAVE","Labor",null,"Intertext","Paul Laurence Dunbar",null,null,"Labor","Slavery","Paul Laurence Dunbar","Intertext","Paul Laurence Dunbar",null,null,null,"Civil War","Patriotism",null,"AAVE","Paul Laurence Dunbar",null,null,null,null,"Ars Poetica",null,"Lynching-and-Racialized-Violence","Africa","Labor",null,null,null,null,null,null,"AAVE",null,null,null,null,null,null,"AAVE",null,null,null,null,"Racism","Childhood",null,null,null,null,null,"Race","Intertext","Paul Laurence Dunbar","Empire","Racism","Intertext","Civil War","Music","Patriotism","Slavery",null,"AAVE","Intertext",null,"Travel-Migration-Great Migration","Caribbean","Caribbean","Interracial-Mixed Race",null,"Intertext",null,"Abraham Lincoln","Brownsville Affair","HBCU","Religion","Labor","Racism",null,"AAVE",null,null,null,"AAVE","Labor","Spanish-American War","Patriotism","Lynching and Racialized Violence",null,null,"Limerick",null,null,null,"Progress-and-Racial Uplift",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"Frederick Douglass",null,null,"Paul Laurence Dunbar",null,null,"Religion",null,null,"Progress and Racial Uplift","Booker T. Washington","",null,"Progress and Racial Uplift","Patriotism","Spanish-American War","Empire","Patriotism","Civil War",null,"Class","Religion","Science","Medicine","AAVE","Progress and Racial Uplift","Religion","Religion","Progress and Racial Uplift","Religion","Ars Poet ...

# %% [markdown]
# In most themes, a bigger percentage of the poems in this theme is written by male poets than female poets.
# Note: this may be due to a misrepresented data size. There are poems written by male poets than female poets.

# %% [markdown]
# ## Violin plots

# %%
# Visualize: Poem length grouped by gender
fig = px.violin(aap, y="Poem_Length",
                x="gender (if known)",
                color = "gender (if known)",
                color_discrete_sequence = ["yellow", "green"])
fig.update_traces(opacity=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="185b7f1d-ca1e-477b-b7ce-73ad950c90a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("185b7f1d-ca1e-477b-b7ce-73ad950c90a7")) {                    Plotly.newPlot(                        "185b7f1d-ca1e-477b-b7ce-73ad950c90a7",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"gender (if known)=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"male","marker":{"color":"yellow"},"name":"male","offsetgroup":"male","orientation":"v","scalegroup":"True","showlegend":true,"x":["male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","m ...

# %% [markdown]
# Male poets write longer poems than female poets.

# %% [markdown]
# ## Line plot

# %%
# Visualize: average `Poem_Length` for every year.
aap_year_length = aap.groupby('year')['Poem_Length'].mean()
fig = px.line(
    aap_year_length,
    x=aap_year_length.index,
    y='Poem_Length',
    title='Average Poem Length Over Years')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a31fb263-ba07-484c-8b9a-93a422a51d48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a31fb263-ba07-484c-8b9a-93a422a51d48")) {                    Plotly.newPlot(                        "a31fb263-ba07-484c-8b9a-93a422a51d48",                        [{"hovertemplate":"year=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928],"xaxis":"x","y":[1786.3333333333333,1113.6470588235295,1596.1666666666667,1457.090909090909,1315.75,801.0147058823529,837.6923076923077,1003.0434782608696,857.25,1187.75,3058.8,832.6,658.6,1910.0,991.1428571428571,1751.6363636363637,903.9473684210526,457.59090909090907,888.5,574.9090909090909,405.73333333333335,659.0,581.3076923076923,510.42424242424244,439.08474576271186,633.0119047619048,517.4675324675325,618.796052631579,661.7474747474747],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overla ...

# %% [markdown]
# Average Poem length peaks in 1910, 1913, and 1915, but have an overall downward trend.

# %% [markdown]
# ## Scatter plot

# %%
# Poem length by year and venue.
fig = px.scatter(aap, x='year', y='Poem_Length',color='venue',
                 title='Poem Length Over Time',
                 labels = {'year':'Year_Published','Poem_length':'Poem_length'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b0526ec8-386f-4462-9a84-4f4e114797d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0526ec8-386f-4462-9a84-4f4e114797d4")) {                    Plotly.newPlot(                        "b0526ec8-386f-4462-9a84-4f4e114797d4",                        [{"hovertemplate":"venue=Colored American \u003cbr\u003eYear_Published=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American ","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Colored American ","orientation":"v","showlegend":true,"x":[1900,1900,1900,1900,1900,1900,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1902,1908,1908],"xaxis":"x","y":[1418,1391,4477,1136,1564,732,1312,943,561,827,514,643,1179,2216,6093,726,1627,1162,944,2575,764,598,840,379,617,520,514],"yaxis":"y","type":"scatter"},{"hovertemplate":"venue=Colored American\u003cbr\u003eYear_Published=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Colored American","orientation":"v","showlegend":true,"x":[1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1902,1902,1905,1905,1905,1908,1908,1908,1908,1908,1908,1908,1908,1908,1908,1909],"xaxis":"x","y":[508,2488,716,291,370,477,661,668,1800,1918,971,971,625,633,426,438,1355,3532,2094,627,585,542,620,780,2709,660,644,1244,605,725,724,344],"yaxis":"y","type":"scatter"},{"hovertemplate":"venue=Colored American Magazine\u003cbr\u003eYear_Published=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American Magazine","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Colored American Magazine","orientation":"v","showlegend":true,"x":[1902,1902,1902,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1904,1904,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909],"xaxis":"x","y":[1642,2103,328,1733,566,521,1963,635,1394,1778,862,959,1912,1301,259,1300,4979,439,622,2142,849,535,702,749,5856,372,603,369,301,402,469,432,423,612,622,606,880,2081,575,825,2769,1384,1032,1942,2132,2124,240,670,1128,1149,622,213,931,1005,430,943,615,606,1712,1278,1043,882,697,782,553,606,414,2287,401,352,603,2302,2829,1079,627,861,1450,358,1488,515,579,1958,1663,2902,2058,421,1318,383,676,909,1479,592,1286,2425,841,839,868],"yaxis":"y","type":"scatter"},{"hovertemplate":"venue=Voice of the Negro\u003cbr\u003eYear_Published=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Voice of the Negro","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Voice of the Negro","orientation":"v","showlegend":true,"x":[1904,1904,1904,1904,1904,1904,1904,1904,1904,1904,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906 ...

# %% [markdown]
# Voice of the Negro published many African American poems from 1904 - 1907
# Colored American Magazine published many African American poems in 1903 and 1909.
# The Crisis published African American poems consistantly from 1911 - 1920

# %%
# Poem length over years facet by gender.
fig = px.scatter(poems_themes, x='year', y='Poem_Length', color='venue', facet_col='gender (if known)',
                 title='Poem Length Over Time by gender',
                 labels={'year': 'Year_Published', 'Poem_Length': 'Poem_Length'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b7a0f3aa-a3f0-40a5-8546-a89b12c1c97a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7a0f3aa-a3f0-40a5-8546-a89b12c1c97a")) {                    Plotly.newPlot(                        "b7a0f3aa-a3f0-40a5-8546-a89b12c1c97a",                        [{"hovertemplate":"venue=Colored American \u003cbr\u003egender (if known)=male\u003cbr\u003eYear_Published=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American ","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Colored American ","showlegend":true,"x":[1900,1900,1900,1900,1900,1900,1900,1900,1900,1900,1900,1900,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1902,1902,1908,1908],"xaxis":"x","y":[1418,1418,4477,1136,1564,1564,1564,1564,1564,732,732,732,1312,943,561,827,514,643,1179,2216,2216,6093,726,1627,1162,944,2575,2575,764,598,617,617,520,514],"yaxis":"y","type":"scattergl"},{"hovertemplate":"venue=Colored American \u003cbr\u003egender (if known)=female\u003cbr\u003eYear_Published=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American ","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Colored American ","showlegend":false,"x":[1900,1901,1901],"xaxis":"x2","y":[1391,840,379],"yaxis":"y2","type":"scattergl"},{"hovertemplate":"venue=Colored American\u003cbr\u003egender (if known)=male\u003cbr\u003eYear_Published=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Colored American","showlegend":true,"x":[1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1901,1902,1902,1902,1905,1905,1905,1908,1908,1908,1908,1908,1908,1908,1908,1909],"xaxis":"x","y":[2488,716,291,370,477,661,668,1800,1918,1918,971,971,625,633,426,438,1355,3532,3532,2094,627,585,542,620,780,2709,660,605,725,724,344],"yaxis":"y","type":"scattergl"},{"hovertemplate":"venue=Colored American\u003cbr\u003egender (if known)=female\u003cbr\u003eYear_Published=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Colored American","showlegend":false,"x":[1901,1908],"xaxis":"x2","y":[508,644],"yaxis":"y2","type":"scattergl"},{"hovertemplate":"venue=Colored American Magazine\u003cbr\u003egender (if known)=male\u003cbr\u003eYear_Published=%{x}\u003cbr\u003ePoem_Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colored American Magazine","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Colored American Magazine","showlegend":true,"x":[1902,1902,1902,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1903,1904,1904,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1905,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1906,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1907,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909,1909],"xaxis":"x","y":[1642,328,328,566,1963,1963,1963,635,1778,1778,959,1912,1912,1301,259,1300,1300,4979,4979,4979,622,2142,2142,849,535,5856,5856,372,603,301,402,469,432,423,612,622,606,880,2081,575,825,2769,1384,1032,1942,1942,2132,2124,2124,1128,1128,1149,1149,622,213,931,1005,430,943,615,606,1712,1043,882,697,782,782,553,414,2287,2287,2287,401,352,603,2829,1079,627,358,579,1958,1663 ...

# %% [markdown]
# More poems by male poets are published than woman.
